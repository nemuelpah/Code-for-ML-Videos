# %%
import os

if not os.path.exists('data'):
    for folder in ['train', 'val']:
        for split in ['1parang', '2megamendung', '3kawung']:
            os.makedirs(f'data/{folder}/{split}')

# %%
from bing_image_downloader import downloader

# %%
downloader.download("batik kawung", limit=50, output_dir="data", adult_filter_off=True)
# Out:
# [%] Downloading Images to C:\Users\nemue\OneDrive - RMIT University\Documents\JTEUS2022\AI 2023\VideoBatik\data\batik kawung
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 39 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://marinaelphick.files.wordpress.com/2014/02/image19.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://png.pngtree.com/png-clipart/20201208/original/pngtree-indonesian-batik-pattern-stamp-brown-kawung-hand-drawn-png-image_5526654.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://marinaelphick.files.wordpress.com/2014/02/image15.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://2.bp.blogspot.com/-oNrnN7K3wGo/UvTTGLaplXI/AAAAAAAAAJw/Pm4S9nhb5Xs/s1600/bfe1d849b5bcc69c6df957e34dea1e25.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://media.istockphoto.com/vectors/beautiful-motifs-of-kawung-batik-with-soft-white-brown-color-design-vector-id1222363858?s=612x612
# [%] File Downloaded !
# ...
